# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import metrics 
import warnings
import cufflinks as cf
import plotly.offline
cf.go_offline()

warnings.simplefilter("ignore")

# %matplotlib inline
TEST_SIZE = 0.0

df = pd.DataFrame(pd.read_csv('train.csv').set_index('PassengerId'))

labels = df['Survived']

# keep track of the length of the original train df
TRAIN_NUM = len(df)

print(TRAIN_NUM)

# concatenate
if TEST_SIZE == 0:
    test_df = pd.DataFrame(pd.read_csv('test.csv').set_index('PassengerId'))
    df = pd.concat([df, test_df])
    
display(df)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 891
#               Age Cabin Embarked      Fare  \
# PassengerId
# 1            22.0   NaN        S    7.2500
# 2            38.0   C85        C   71.2833
# 3            26.0   NaN        S    7.9250
# 4            35.0  C123        S   53.1000
# 5            35.0   NaN        S    8.0500
# ...           ...   ...      ...       ...
# 1305          NaN   NaN        S    8.0500
# 1306         39.0  C105        C  108.9000
# 1307         38.5   NaN        S    7.2500
# 1308          NaN   NaN        S    8.0500
# 1309          NaN   NaN        C   22.3583
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
# ...                                                        ...    ...     ...
# 1305                                        Spector, Mr. Woolf      0       3
# 1306                              Oliva y Ocana, Dona. Fermina      0       1
# 1307                              Saether, Mr. Simon Sivertsen      0       3
# 1308                                       Ware, Mr. Frederick      0       3
# 1309                                  Peter, Master. Michael J      1       3
#
#                 Sex  SibSp  Survived              Ticket
# PassengerId
# 1              male      1       0.0           A/5 21171
# 2            female      1       1.0            PC 17599
# 3            female      0       1.0    STON/O2. 3101282
# 4            female      1       1.0              113803
# 5              male      0       0.0              373450
# ...             ...    ...       ...                 ...
# 1305           male      0       NaN           A.5. 3236
# 1306         female      0       NaN            PC 17758
# 1307           male      0       NaN  SOTON/O.Q. 3101262
# 1308           male      0       NaN              359309
# 1309           male      1       NaN                2668
#
# [1309 rows x 11 columns]

# %% [markdown]
# ### Summary Function for Initial DataFrame

# %%
def summary(df):
    ret = {}
    ret['null'] = df.isnull().sum()
    ret['null_avg'] = df.isnull().mean()
    ret['dtypes'] = df.dtypes
    ret['count'] = df.count()
    ret['mean'] = df.mean()
    ret['median'] = df.median()
    ret['min'] = df.min()
    ret['max'] = df.max()
    return pd.DataFrame(ret)

display(summary(df))
print(df.dtypes.value_counts())
# Out:
#           null  null_avg   dtypes  count       mean   median  \
# Age        263  0.200917  float64   1046  29.881138  28.0000
# Cabin     1014  0.774637   object    295        NaN      NaN
# Embarked     2  0.001528   object   1307        NaN      NaN
# Fare         1  0.000764  float64   1308  33.295479  14.4542
# Name         0  0.000000   object   1309        NaN      NaN
# Parch        0  0.000000    int64   1309   0.385027   0.0000
# Pclass       0  0.000000    int64   1309   2.294882   3.0000
# Sex          0  0.000000   object   1309        NaN      NaN
# SibSp        0  0.000000    int64   1309   0.498854   0.0000
# Survived   418  0.319328  float64    891   0.383838   0.0000
# Ticket       0  0.000000   object   1309        NaN      NaN
#
#                           min                          max
# Age                      0.17                           80
# Cabin                     NaN                          NaN
# Embarked                  NaN                          NaN
# Fare                        0                      512.329
# Name      Abbing, Mr. Anthony  van Melkebeke, Mr. Philemon
# Parch                       0                            9
# Pclass                      1                            3
# Sex                    female                         male
# SibSp                       0                            8
# Survived                    0                            1
# Ticket                 110152                    WE/P 5735
# object     5
# float64    3
# int64      3
# dtype: int64

# %% [markdown]
# ### Imputation for categories with only few null values
# We perform mode imputation and mean imputation with the 2 missing embarked and 1 missing fare points respectively

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode())
df['Fare'] = df['Fare'].fillna(df['Fare'].mean())

# %% [markdown]
# ### Prerocess Name

# %%
df['married'] = 0
df['avg_name_length'] = 0

def preprocess_name(row):
    row['married'] = 1 if 'Mrs' in str(row['Name']) else 0
    row['avg_name_length'] = len(row['Name'])/len(row['Name'].split())
    return row

df = df.apply(preprocess_name, axis=1)

# %% [markdown]
# ### Turn pclass and embarked Class into 3 Dummy Variables and Drop nan's

# %%
# df = df[df['Pclass'].notna()][df['Embarked'].notna()]
dummies_embarked = pd.get_dummies(df['Embarked'], prefix='embark')
dummies_pclass = pd.get_dummies(df['Pclass'], prefix='pclass')
df = pd.concat([df, dummies_embarked, dummies_pclass], axis = 1).drop(columns=['Pclass', 'Embarked'])

# %% [markdown]
# ### Preprocess Cabin Info

# %%
df['top_levels'] = 0
df['bottom_levels'] = 0
df['nan_level'] = 0
def preprocess_cabin(row):
    top = ['A', 'B', 'C']
    bottom = ['D', 'E', 'F']
    cabin = str(row['Cabin'])[0] if str(row['Cabin']) != 'nan' else 'N'
    if cabin in top:
        row['top_levels'] = 1
    elif cabin in bottom:
        row['bottom_levels'] = 1
    elif cabin == 'N':
        row['nan_level'] = 1
    return row

df = df.apply(preprocess_cabin, axis=1)
dummies_cabin = pd.get_dummies(df['Cabin'], prefix='cabin_level')
df = df.drop(columns=['Cabin'])

# %% [markdown]
# ## Imputation for Age : because it is a small dataset, we can try both mean imputation and KNN
# Before checking mean imputation, let's view the age distribution in a histogram and qq plot to verify normality|

# %%
from statsmodels.graphics.gofplots import qqplot

def normalize_age(row):
    if str(row['Age']) == 'nan':
        row['Age'] = df['Age'].mean()
        
    return row

imputation = 'Norm'

df['Age'] = df['Age'].fillna(float('nan'))
    
if imputation == 'Norm':

    df[df['Age'].notna()]['Age'].hist()
    # we can see it is kind of a right-skewed normal distribution
    qqplot(df[df['Age'].notna()]['Age'], line='s')

    df = df.apply(normalize_age, axis = 1)
    df[df['Age'].notna()]['Age'].hist()
    
elif imputation == 'KNN':

    display(summary(df))
    from sklearn.impute import KNNImputer
    # train_features.fillna(float('nan'))
    imputer = KNNImputer(missing_values=float('nan'), n_neighbors=20)
    df['Age'] = imputer.fit_transform(df.drop(columns=['Survived', 'Name', 'Ticket', 'Sex'])
                                  , y=df['Age'])
display(summary(df))
# Out:
#                  null  null_avg   dtypes  count       mean   median  \
# Age               263  0.200917  float64   1046  29.881138  28.0000
# Fare                0  0.000000  float64   1309  33.295479  14.4542
# Name                0  0.000000   object   1309        NaN      NaN
# Parch               0  0.000000    int64   1309   0.385027   0.0000
# Sex                 0  0.000000   object   1309        NaN      NaN
# SibSp               0  0.000000    int64   1309   0.498854   0.0000
# Survived          418  0.319328  float64    891   0.383838   0.0000
# Ticket              0  0.000000   object   1309        NaN      NaN
# avg_name_length     0  0.000000  float64   1309   6.578033   6.5000
# bottom_levels       0  0.000000    int64   1309   0.082506   0.0000
# embark_C            0  0.000000    int64   1309   0.206264   0.0000
# embark_Q            0  0.000000    int64   1309   0.093965   0.0000
# embark_S            0  0.000000    int64   1309   0.698243   1.0000
# married             0  0.000000    int64   1309   0.153552   0.0000
# nan_level           0  0.000000    int64   1309   0.774637   1.0000
# pclass_1            0  0.000000    int64   1309   0.246753   0.0000
# pclass_2            0  0.000000    int64   1309   0.211612   0.0000
# pclass_3            0  0.000000    int64   1309   0.541635   1.0000
# top_levels          0  0.000000    int64   1309   0.138273   0.0000
#
#                                  min                          max
# Age                             0.17                           80
# Fare                               0                      512.329
# Name             Abbing, Mr. Anthony  van Melkebeke, Mr. Philemon
# Parch                              0                            9
# Sex                           female                         male
# SibSp                              0                            8
# Survived                           0                            1
# Ticket                        110152                    WE/P 5735
# avg_name_length                    4                           11
# bottom_levels                      0                            1
# embark_C                           0                            1
# embark_Q                           0                            1
# embark_S                           0                            1
# married                            0                            1
# nan_level                          0                            1
# pclass_1                           0                            1
# pclass_2                           0                            1
# pclass_3                           0                            1
# top_levels                         0                            1
#                  null  null_avg   dtypes  count       mean   median  \
# Age                 0  0.000000  float64   1309  29.709963  28.0000
# Fare                0  0.000000  float64   1309  33.295479  14.4542
# Name                0  0.000000   object   1309        NaN      NaN
# Parch               0  0.000000    int64   1309   0.385027   0.0000
# Sex                 0  0.000000   object   1309        NaN      NaN
# SibSp               0  0.000000    int64   1309   0.498854   0.0000
# Survived          418  0.319328  float64    891   0.383838   0.0000
# Ticket              0  0.000000   object   1309        NaN      NaN
# avg_name_length     0  0.000000  float64   1309   6.578033   6.5000
# bottom_levels       0  0.000000    int64   1309   0.082506   0.0000
# embark_C            0  0.000000    int64   1309   0.206264   0.0000
# embark_Q            0  0.000000    int64   1309   0.093965   0.0000
# embark_S            0  0.000000    int64   1309   0.698243   1.0000
# married             0  0.000000    int64   1309   0.153552   0.0000
# nan_level           0  0.000000    int64   1309   0.774637   1.0000
# pclass_1            0  0.000000    int64   1309   0.246753   0.0000
# pclass_2            0  0.000000    int64   1309   0.211612   0.0000
# pclass_3            0  0.000000    int64   1309   0.541635   1.0000
# top_levels          0  0.000000    int64   1309   0.138273   0.0000
#
#                                  min                          max
# Age                             0.17                           80
# Fare                               0                      512.329
# Name             Abbing, Mr. Anthony  van Melkebeke, Mr. Philemon
# Parch                              0                            9
# Sex                           female                         male
# SibSp                              0                            8
# Survived                           0                            1
# Ticket                        110152                    WE/P 5735
# avg_name_length                    4                           11
# bottom_levels                      0                            1
# embark_C                           0                            1
# embark_Q                           0                            1
# embark_S                           0                            1
# married                            0                            1
# nan_level                          0                            1
# pclass_1                           0                            1
# pclass_2                           0                            1
# pclass_3                           0                            1
# top_levels                         0                            1

# %% [markdown]
# ### Preprocess sex

# %%
def preprocess_sex(row):
    if row['Age'] < 18:
        row['Sex'] = 'Youth'
#     else:
#         row['Sex'] = 1 if (row['Sex'] == 'female') else 0
    return row
    
df = df.apply(preprocess_sex, axis = 1)
dummies_sex = pd.get_dummies(df['Sex'], prefix='sex')
df = pd.concat([df, dummies_sex], axis = 1).drop(columns=['Sex'])

# %% [markdown]
# ## Final Cell of Analysis

# %%
display(df.iloc[:TRAIN_NUM])
df.iloc[:TRAIN_NUM].corr().iplot(kind='heatmap',colorscale="RdBu", title="Married/Survived Correlation Matrix")
print(summary(df))
# Out:
#                  Age     Fare  \
# PassengerId
# 1            22.0000   7.2500
# 2            38.0000  71.2833
# 3            26.0000   7.9250
# 4            35.0000  53.1000
# 5            35.0000   8.0500
# ...              ...      ...
# 887          27.0000  13.0000
# 888          19.0000  30.0000
# 889          20.9085  23.4500
# 890          26.0000  30.0000
# 891          32.0000   7.7500
#
#                                                           Name  Parch  SibSp  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0      1
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0      1
# 3                                       Heikkinen, Miss. Laina      0      0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0      1
# 5                                     Allen, Mr. William Henry      0      0
# ...                                                        ...    ...    ...
# 887                                      Montvila, Rev. Juozas      0      0
# 888                               Graham, Miss. Margaret Edith      0      0
# 889                   Johnston, Miss. Catherine Helen "Carrie"      2      1
# 890                                      Behr, Mr. Karl Howell      0      0
# 891                                        Dooley, Mr. Patrick      0      0
#
#              Survived            Ticket  married  avg_name_length  embark_C  \
# PassengerId
# 1                 0.0         A/5 21171        0         5.750000         0
# 2                 1.0          PC 17599        1         7.285714         1
# 3                 1.0  STON/O2. 3101282        0         7.333333         0
# 4                 1.0            113803        1         6.285714         0
# 5                 0.0            373450        0         6.000000         0
# ...               ...               ...      ...              ...       ...
# 887               0.0            211536        0         7.000000         0
# 888               1.0            112053        0         7.000000         0
# 889               0.0        W./C. 6607        0         8.000000         0
# 890               1.0            111369        0         5.250000         1
# 891               0.0            370376        0         6.333333         0
#
#              ...  embark_S  pclass_1  pclass_2  pclass_3  top_levels  \
# PassengerId  ...
# 1            ...         1         0         0         1           0
# 2            ...         0         1         0         0           1
# 3            ...         1         0         0         1           0
# 4            ...         1         1         0         0           1
# 5            ...         1         0         0         1           0
# ...          ...       ...       ...       ...       ...         ...
# 887          ...         1         0         1         0           0
# 888          ...         1         1         0         0           1
# 889          ...         1         0         0         1           0
# 890          ...         0         1         0         0           1
# 891          ...         0         0         0         1           0
#
#              bottom_levels  nan_level  sex_Youth  sex_female  sex_male
# PassengerId
# 1                        0          1          0           0         1
# 2                        0          0          0           1         0
# 3                        0          1          0           1         0
# 4                        0          0          0           1         0
# 5                        0          1          0           0         1
# ...                    ...        ...        ...         ...       ...
# 887                      0          1          0           0         1
# 888                      0          0          0           1         0
# 889                      0          1          0           1         0
# 890                      0          0          0           0         1
# 891                      0          1          0           0         1
#
# [891 rows x 21 columns]
# <div>
#
#
#             <div id="ec52881c-b2e0-4ddb-b363-5d51dc12e8d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ec52881c-b2e0-4ddb-b363-5d51dc12e8d2")) {
#                     Plotly.newPlot(
#                         'ec52881c-b2e0-4ddb-b363-5d51dc12e8d2',
#                         [{"colorscale": [[0.0, "rgb(103,0,31)"], [0.1, "rgb(178,24,43)"], [0.2, "rgb(214,96,77)"], [0.3, "rgb(244,165,130)"], [0.4, "rgb(253,219,199)"], [0.5, "rgb(247,247,247)"], [0.6, "rgb(209,229,240)"], [0.7, "rgb(146,197,222)"], [0.8, "rgb(67,147,195)"], [0.9, "rgb(33,102,172)"], [1.0, "rgb(5,48,97)"]], "type": "heatmap", "x": ["Age", "Fare", "Parch", "SibSp", "Survived", "married", "avg_name_length", "embark_C", "embark_Q", "embark_S", "pclass_1", "pclass_2", "pclass_3", "top_levels", "bottom_levels", "nan_level", "sex_Youth", "sex_female", "sex_male"], "y": ["Age", "Fare", "Parch", "SibSp", "Survived", "married", "avg_name_length", "embark_C", "embark_Q", "embark_S", "pclass_1", "pclass_2", "pclass_3", "top_levels", "bottom_levels", "nan_level", "sex_Youth", "sex_female", "sex_male"], "z": [[1.0, 0.11216621256145841, -0.183641018768714, -0.2363431878858626, -0.06067206392993019, 0.16759436846124248, -0.08400957443405956, 0.02793106280142293, -0.04224511853703491, -0.005604425957657102, 0.36888404146842996, 0.01739171954053962, -0.33198656059092063, 0.21752237482861525, 0.14086136938019087, -0.2632022576038986, -0.5962524229731275, 0.11541223830486261, 0.30026485147183407], [0.11216621256145841, 1.0, 0.21622494477076254, 0.15965104324216103, 0.2573065223849618, 0.10378506379519635, 0.06530457640935008, 0.26933473491526394, -0.11721599017237648, -0.16660270235034377, 0.5917107188835107, -0.1185566980395822, -0.4133325422867402, 0.5238429807254017, 0.08739658005896295, -0.482075352452561, -0.01056178941561281, 0.1902434677692722, -0.1677766023198934], [-0.183641018768714, 0.21622494477076254, 1.0, 0.41483769862015263, 0.08162940708348222, 0.21686194536184178, 0.16741191031610267, -0.011068771902447054, -0.0812281037127347, 0.06303616946304659, -0.017633491175154125, -0.0007338972396312793, 0.015790384600964897, 0.04403058974625897, -0.013626116864867201, -0.036987034298118136, 0.317681816806773, 0.14778188663885708, -0.35245861035818027], [-0.2363431878858626, 0.15965104324216103, 0.41483769862015263, 1.0, -0.03532249888573588, 0.059419363960380715, 0.12137637523404893, -0.05952821504870246, -0.026353729241718093, 0.07094062735099396, -0.05458155100768302, -0.05593163590694451, 0.09254804631012825, -0.01867944999375446, -0.03529100828530628, 0.04046001036349831, 0.3247992796587286, 0.03709554839478374, -0.25550665868468403], [-0.06067206392993019, 0.2573065223849618, 0.08162940708348222, -0.03532249888573588, 1.0, 0.34422315890655236, 0.2543395400670901, 0.16824043121823343, 0.003650382683972286, -0.15566027340439476, 0.28590376778374027, 0.09334857241192815, -0.3223083573729687, 0.20584039918620675, 0.22096496697085696, -0.3169115231122935, 0.12670015430374193, 0.48580692709551615, -0.5331797773739179], [0.16759436846124248, 0.10378506379519635, 0.21686194536184178, 0.059419363960380715, 0.34422315890655236, 1.0, 0.22726151393506341, 0.07075213392109826, -0.09249254187123972, -0.008828874068539633, 0.09472441934290005, 0.12890720575445988, -0.18652697459695822, 0.07896579892725168, 0.07569124937449415, -0.1249868494117282, -0.12126980092842374, 0.6146294289860047, -0.4826436386090252], [-0.08400957443405956, 0.06530457640935008, 0.16741191031610267, 0.12137637523404893, 0.2543395400670901, 0.22726151393506341, 1.0, 0.03885330260426221, -0.05147231010562868, -0.0016742338267289008, 0.10753770193188596, -0.012436920221530855, -0.0825331117730397, 0.09254009389987575, 0.02911061543184251, -0.10651642972518495, 0.13239683625057083, 0.28033127243410605, -0.34807729923868286], [0.02793106280142293, 0.26933473491526394, -0.011068771902447054, -0.05952821504870246, 0.16824043121823343, 0.07075213392109826, 0.03885330260426221, 1.0, -0.14825817586486686, -0.7783589961128763, 0.2964226793966662, -0.12541560201318058, -0.1533288384058338, 0.22769220482170222, 0.043582794736712074, -0.20852753758866016, 0.035197197858248305, 0.04527523025285041, -0.06563266496293164], [-0.04224511853703491, -0.11721599017237648, -0.08 ...
#                  null  null_avg   dtypes  count       mean   median  \
# Age                 0  0.000000  float64   1309  29.709963  28.0000
# Fare                0  0.000000  float64   1309  33.295479  14.4542
# Name                0  0.000000   object   1309        NaN      NaN
# Parch               0  0.000000    int64   1309   0.385027   0.0000
# SibSp               0  0.000000    int64   1309   0.498854   0.0000
# Survived          418  0.319328  float64    891   0.383838   0.0000
# Ticket              0  0.000000   object   1309        NaN      NaN
# avg_name_length     0  0.000000  float64   1309   6.578033   6.5000
# bottom_levels       0  0.000000    int64   1309   0.082506   0.0000
# embark_C            0  0.000000    int64   1309   0.206264   0.0000
# embark_Q            0  0.000000    int64   1309   0.093965   0.0000
# embark_S            0  0.000000    int64   1309   0.698243   1.0000
# married             0  0.000000    int64   1309   0.153552   0.0000
# nan_level           0  0.000000    int64   1309   0.774637   1.0000
# pclass_1            0  0.000000    int64   1309   0.246753   0.0000
# pclass_2            0  0.000000    int64   1309   0.211612   0.0000
# pclass_3            0  0.000000    int64   1309   0.541635   1.0000
# sex_Youth           0  0.000000    uint8   1309   0.120703   0.0000
# sex_female          0  0.000000    uint8   1309   0.300229   0.0000
# sex_male            0  0.000000    uint8   1309   0.579068   1.0000
# top_levels          0  0.000000    int64   1309   0.138273   0.0000
#
#                                  min                          max
# Age                             0.17                           80
# Fare                               0                      512.329
# Name             Abbing, Mr. Anthony  van Melkebeke, Mr. Philemon
# Parch                              0                            9
# SibSp                              0                            8
# Survived                           0                            1
# Ticket                        110152                    WE/P 5735
# avg_name_length                    4                           11
# bottom_levels                      0                            1
# embark_C                           0                            1
# embark_Q                           0                            1
# embark_S                           0                            1
# married                            0                            1
# nan_level                          0                            1
# pclass_1                           0                            1
# pclass_2                           0                            1
# pclass_3                           0                            1
# sex_Youth                          0                            1
# sex_female                         0                            1
# sex_male                           0                            1
# top_levels                         0                            1

# %% [markdown]
# # Model Starts Here

# %% [markdown]
# ### Split into Train/Val (if val necessary)

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
import time

features = df.drop(columns=['Survived', 'Name', 'Ticket', 'Age'])
labels = df['Survived']

if TEST_SIZE:
    train_features, test_features, train_labels, test_labels = train_test_split(features, labels,
                                                                            test_size=TESTSIZE)

else:
    train_features, test_features, train_labels = features.iloc[:TRAIN_NUM], features.iloc[TRAIN_NUM:], labels.iloc[:TRAIN_NUM]
    
display('Train Features', train_features)
display('Test Features', test_features)
# Out:
# 'Train Features'
#                 Fare  Parch  SibSp  married  avg_name_length  embark_C  \
# PassengerId
# 1             7.2500      0      1        0         5.750000         0
# 2            71.2833      0      1        1         7.285714         1
# 3             7.9250      0      0        0         7.333333         0
# 4            53.1000      0      1        1         6.285714         0
# 5             8.0500      0      0        0         6.000000         0
# ...              ...    ...    ...      ...              ...       ...
# 887          13.0000      0      0        0         7.000000         0
# 888          30.0000      0      0        0         7.000000         0
# 889          23.4500      2      1        0         8.000000         0
# 890          30.0000      0      0        0         5.250000         1
# 891           7.7500      0      0        0         6.333333         0
#
#              embark_Q  embark_S  pclass_1  pclass_2  pclass_3  top_levels  \
# PassengerId
# 1                   0         1         0         0         1           0
# 2                   0         0         1         0         0           1
# 3                   0         1         0         0         1           0
# 4                   0         1         1         0         0           1
# 5                   0         1         0         0         1           0
# ...               ...       ...       ...       ...       ...         ...
# 887                 0         1         0         1         0           0
# 888                 0         1         1         0         0           1
# 889                 0         1         0         0         1           0
# 890                 0         0         1         0         0           1
# 891                 1         0         0         0         1           0
#
#              bottom_levels  nan_level  sex_Youth  sex_female  sex_male
# PassengerId
# 1                        0          1          0           0         1
# 2                        0          0          0           1         0
# 3                        0          1          0           1         0
# 4                        0          0          0           1         0
# 5                        0          1          0           0         1
# ...                    ...        ...        ...         ...       ...
# 887                      0          1          0           0         1
# 888                      0          0          0           1         0
# 889                      0          1          0           1         0
# 890                      0          0          0           0         1
# 891                      0          1          0           0         1
#
# [891 rows x 17 columns]
# 'Test Features'
#                  Fare  Parch  SibSp  married  avg_name_length  embark_C  \
# PassengerId
# 892            7.8292      0      0        0         5.333333         0
# 893            7.0000      0      1        1         6.400000         0
# 894            9.6875      0      0        0         6.250000         0
# 895            8.6625      0      0        0         5.333333         0
# 896           12.2875      1      1        1         7.333333         0
# ...               ...    ...    ...      ...              ...       ...
# 1305           8.0500      0      0        0         6.000000         0
# 1306         108.9000      0      0        0         5.600000         1
# 1307           7.2500      0      0        0         7.000000         0
# 1308           8.0500      0      0        0         6.333333         0
# 1309          22.3583      1      1        0         6.000000         1
#
#              embark_Q  embark_S  pclass_1  pclass_2  pclass_3  top_levels  \
# PassengerId
# 892                 1         0         0         0         1           0
# 893                 0         1         0         0         1           0
# 894                 1         0         0         1         0           0
# 895                 0         1         0         0         1           0
# 896                 0         1         0         0         1           0
# ...               ...       ...       ...       ...       ...         ...
# 1305                0         1         0         0         1           0
# 1306                0         0         1         0         0           1
# 1307                0         1         0         0         1           0
# 1308                0         1         0         0         1           0
# 1309                0         0         0         0         1           0
#
#              bottom_levels  nan_level  sex_Youth  sex_female  sex_male
# PassengerId
# 892                      0          1          0           0         1
# 893                      0          1          0           1         0
# 894                      0          1          0           0         1
# 895                      0          1          0           0         1
# 896                      0          1          0           1         0
# ...                    ...        ...        ...         ...       ...
# 1305                     0          1          0           0         1
# 1306                     0          0          0           1         0
# 1307                     0          1          0           0         1
# 1308                     0          1          0           0         1
# 1309                     0          1          0           0         1
#
# [418 rows x 17 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

time_start = time.time()

forest = RandomForestClassifier()
search_space = {'n_estimators': [64, 128],
                'max_leaf_nodes': [None, 32, 64],
                'max_depth':[None]
               }

forest_cv_grid = GridSearchCV(forest, search_space, cv=2)

forest_cv_grid.fit(train_features, train_labels)

forest = forest_cv_grid.best_estimator_
forest.fit(train_features, train_labels)
print('DONE Forest training! took {} seconds'.format(time.time() - time_start))

forest_results = pd.DataFrame(forest_cv_grid.cv_results_)
ranked = forest_results.sort_values(['rank_test_score'])
display(ranked[:5])

forest_predictions = forest.predict(test_features)
final_df = pd.DataFrame(forest_predictions, columns = ['Survived']).astype({'Survived': int})
display(final_df)
final_df['PassengerId'] = final_df.index + TRAIN_NUM + 1


final_df.set_index('PassengerId', inplace=True)
display(final_df)
# Out:
# DONE Forest training! took 19.54018497467041 seconds
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 7       0.881856      0.056982         0.095170        0.000497
# 5       0.226325      0.012307         0.023378        0.000915
# 6       0.444418      0.028521         0.049887        0.002291
# 4       0.105952      0.002040         0.014083        0.001651
# 1       0.230346      0.001874         0.026643        0.001867
#
#   param_max_depth param_max_leaf_nodes param_n_estimators  \
# 7            None                   64                512
# 5            None                   64                128
# 6            None                   64                256
# 4            None                   64                 64
# 1            None                 None                128
#
#                                               params  split0_test_score  \
# 7  {'max_depth': None, 'max_leaf_nodes': 64, 'n_e...           0.831650
# 5  {'max_depth': None, 'max_leaf_nodes': 64, 'n_e...           0.818182
# 6  {'max_depth': None, 'max_leaf_nodes': 64, 'n_e...           0.818182
# 4  {'max_depth': None, 'max_leaf_nodes': 64, 'n_e...           0.818182
# 1  {'max_depth': None, 'max_leaf_nodes': None, 'n...           0.808081
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 7           0.835017           0.801347         0.822671        0.015141
# 5           0.838384           0.808081         0.821549        0.012598
# 6           0.831650           0.804714         0.818182        0.010997
# 4           0.818182           0.797980         0.811448        0.009523
# 1           0.835017           0.781145         0.808081        0.021993
#
#    rank_test_score
# 7                1
# 5                2
# 6                3
# 4                4
# 1                5
#      Survived
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 413         0
# 414         1
# 415         0
# 416         0
# 417         0
#
# [418 rows x 1 columns]
#              Survived
# PassengerId
# 892                 0
# 893                 0
# 894                 0
# 895                 0
# 896                 0
# ...               ...
# 1305                0
# 1306                1
# 1307                0
# 1308                0
# 1309                0
#
# [418 rows x 1 columns]

# %% [markdown]
# ## Metrics if Test set part of the train.csv, otherwise write to a csv file

# %%
if TEST_SIZE:

    confusion_mat = confusion_matrix(test_labels, forest_predictions)

    fig, ax = plt.subplots(figsize=(15, 15))
    sns.heatmap(confusion_mat.T,
                square=True,
                annot=True,
                fmt='d',
                cbar=False,
                linewidths=.5,
                xticklabels=["Survived", "Did Not Survive"],
                yticklabels=["Survived", "Did Not Survive"],
                ax=ax)

    plt.xlabel('True Value');plt.ylabel('Predicted Value')
    plt.title('Confusion Matrix of Random Forest Predictions for Titanic Dataset')
    bottom, top = ax.get_ylim()
    ax.set_ylim(bottom + 0.5, top - 0.5)
    plt.show()
    
else:
    final_df.to_csv("submission.csv")
