# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import metrics 
import warnings
warnings.simplefilter("ignore")
df = pd.DataFrame(pd.read_csv('train.csv'))
df["Name_Length"] = df["Name"].apply(len)
display(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### preprocess_df adds the missing values and makes categorical values oridnal values to the raw dataframes

# %%
def preprocess_df(dataframe):
    dataframe.replace({'Sex': {'male': 0, 'female' : 1}}, inplace=True)
    dataframe.replace({'Embarked': {'S': 0, 'C' : 1, 'Q' : 2, float('nan'): -1}}, inplace=True)
    dataframe.replace({'Cabin': {float('nan') : 'O00'}}, inplace=True)
    dataframe.replace({'Age': {float('nan') : -1}}, inplace=True)
    dataframe.replace({'Fare': {float('nan') : -1}}, inplace=True)
    dataframe.Sex = dataframe.Sex.astype(int)
    dataframe.Embarked = dataframe.Embarked.astype(int)

# %% [markdown]
# #### prob_plots compares the probability curves of the 2 distributions

# %%
def prob_plots(feature_str):
    
    column = pd.DataFrame(df[feature_str])
    list1 = column[df["Survived"] == 1][feature_str].value_counts()/len(column[df["Survived"] == 1])
    list2 = column[df["Survived"] == 0][feature_str].value_counts()/len(column[df["Survived"] == 0])


    fig = plt.figure(figsize = (16,10))


    plt.title("Comparison of probability distributions of the " + feature_str)
    plt.bar(
            x = range(len(list1)),
            height = [list1[i] for i in range(len(list1))],
            color = "green",
            alpha = 0.3
    )
    plt.bar(
            x = range(len(list2)),
            height = [list2[i] for i in range(len(list2))],
            color = "red",
            alpha = 0.3
    )

# %% [markdown]
# ### Make Train/Test Sets
# X_train, X_test, y_train are the final train and test sets, we will also use preliminary train/test splits using only the info on X_train and y_train to verify the model before submitting to kaggle

# %%
num_survived = len((df["Survived"][df["Survived"] == 1]))
num_not_survived = len((df["Survived"][df["Survived"] == 0]))

# %%
preprocess_df(df)
dropped_columns = ['PassengerId', 'Name','Ticket', 'Cabin']
X_train = df.drop(columns = dropped_columns + ['Survived'])
y_train = df['Survived']

df_test = pd.DataFrame(pd.read_csv('test.csv'))
preprocess_df(df_test)
X_test = df_test.drop(columns = dropped_columns)

display(pd.concat([X_train, y_train], axis = 1))
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Name_Length  Survived
# 0         3    0  22.0      1      0   7.2500         0           23         0
# 1         1    1  38.0      1      0  71.2833         1           51         1
# 2         3    1  26.0      0      0   7.9250         0           22         1
# 3         1    1  35.0      1      0  53.1000         0           44         1
# 4         3    0  35.0      0      0   8.0500         0           24         0
# ..      ...  ...   ...    ...    ...      ...       ...          ...       ...
# 886       2    0  27.0      0      0  13.0000         0           21         0
# 887       1    1  19.0      0      0  30.0000         0           28         1
# 888       3    1  -1.0      1      2  23.4500         0           40         0
# 889       1    0  26.0      0      0  30.0000         1           21         1
# 890       3    0  32.0      0      0   7.7500         2           19         0
#
# [891 rows x 9 columns]

# %%
fig = plt.figure(figsize = (8,6))
sns.distplot(df["Fare"][df["Survived"] == 1], ax = fig.gca(), label = "Fare", color="green", kde=False)
sns.distplot(df["Fare"][df["Survived"] == 0], ax = fig.gca(), label = "Fare", color="red", kde=False)
plt.show()

# %%
fig = plt.figure(figsize = (8,6))
sns.distplot(df["Name_Length"][df["Survived"] == 1], ax = fig.gca(), label = "Name_Length", color="green", kde=False)
sns.distplot(df["Name_Length"][df["Survived"] == 0], ax = fig.gca(), label = "Name_Length", color="red", kde=False)
plt.show()

# %%
fig = plt.figure(figsize = (8,6))
sns.distplot(df["Pclass"][df["Survived"] == 1], bins = 3, ax = fig.gca(), label = "Pclass", color="green", kde=False)
sns.distplot(df["Pclass"][df["Survived"] == 0], bins = 3, ax = fig.gca(), label = "Pclass", color="red", kde=False)
plt.show()

# %%
fig = plt.figure(figsize = (8,6))
sns.distplot(df["Sex"][df["Survived"] == 1], ax = fig.gca(), label = "Sex", color="green", kde=False)
sns.distplot(df["Sex"][df["Survived"] == 0], ax = fig.gca(), label = "Sex", color="red", kde=False)
plt.show()

# %%
fig = plt.figure(figsize = (8,6))
sns.distplot(df["Embarked"][df["Survived"] == 1], ax = fig.gca(), label = "Embarked", color="green", kde=False)
sns.distplot(df["Embarked"][df["Survived"] == 0], ax = fig.gca(), label = "Embarked", color="red", kde=False)
plt.show()

# %%
prob_plots("Embarked")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-115-372da37f3b18> in <module>
# ----> 1 prob_plots("Embarked")
#
# <ipython-input-114-7ec74662675c> in prob_plots(feature_str)
#      12     plt.bar(
#      13             x = range(len(list1)),
# ---> 14             height = [list1[i] for i in range(len(list1))],
#      15             color = "green",
#      16             alpha = 0.3
#
# <ipython-input-114-7ec74662675c> in <listcomp>(.0)
#      12     plt.bar(
#      13             x = range(len(list1)),
# ---> 14             height = [list1[i] for i in range(len(list1))],
#      15             color = "green",
#      16             alpha = 0.3
#
# ~\Anaconda3\envs\jupyter\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1069         key = com.apply_if_callable(key, self)
#    1070         try:
# ...

# %%
plt.figure(figsize=(16, 12))
temp = pd.DataFrame(pd.concat([X_train, y_train], axis = 1))
ax = sns.heatmap(temp.corr(), annot=True)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline

# %% [markdown]
# #### Baseline Classifier

# %%
print(X_train.describe())
# Out:
#            Pclass         Sex         Age       SibSp       Parch        Fare  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     2.308642    0.352413   23.600640    0.523008    0.381594   32.204208
# std      0.836071    0.477990   17.867496    1.102743    0.806057   49.693429
# min      1.000000    0.000000   -1.000000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000    6.000000    0.000000    0.000000    7.910400
# 50%      3.000000    0.000000   24.000000    0.000000    0.000000   14.454200
# 75%      3.000000    1.000000   35.000000    1.000000    0.000000   31.000000
# max      3.000000    1.000000   80.000000    8.000000    6.000000  512.329200
#
#          Embarked  Name_Length
# count  891.000000   891.000000
# mean     0.359147    26.965208
# std      0.638707     9.281607
# min     -1.000000    12.000000
# 25%      0.000000    20.000000
# 50%      0.000000    25.000000
# 75%      1.000000    30.000000
# ...

# %%
NUM_TESTS = 3000

def test_estimator(test_features, num_tests):
    f1_no = list()
    f1_yes = list()
    display(test_features)
    for i in range(num_tests):
        Estimator = RandomForestClassifier()
        X_prelim_train, X_prelim_test, y_prelim_train, y_prelim_test = train_test_split(test_features, y_train, test_size = 0.15)
        Estimator.fit(X_prelim_train, y_prelim_train) 
        Estimator_predictions = Estimator.predict(X_prelim_test)
        prec, rec, f1, sup = metrics.precision_recall_fscore_support(y_prelim_test, Estimator_predictions)
        no, yes = f1[0], f1[1]
        f1_no.append(no); f1_yes.append(yes)

    return f1_no, f1_yes
            
def paired_hist(plt1, plt2, c1, c2):
    sns.distplot(plt1, bins = 10, color = c1)
    sns.distplot(plt2, bins = 10, color = c2)

# %%
train = X_train.drop(columns = ["Name_Length"])
no, yes = test_estimator(train, NUM_TESTS)
no2, yes2 = test_estimator(X_train, NUM_TESTS)
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         3    0  22.0      1      0   7.2500         0
# 1         1    1  38.0      1      0  71.2833         1
# 2         3    1  26.0      0      0   7.9250         0
# 3         1    1  35.0      1      0  53.1000         0
# 4         3    0  35.0      0      0   8.0500         0
# ..      ...  ...   ...    ...    ...      ...       ...
# 886       2    0  27.0      0      0  13.0000         0
# 887       1    1  19.0      0      0  30.0000         0
# 888       3    1  -1.0      1      2  23.4500         0
# 889       1    0  26.0      0      0  30.0000         1
# 890       3    0  32.0      0      0   7.7500         2
#
# [891 rows x 7 columns]
#      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Name_Length
# 0         3    0  22.0      1      0   7.2500         0           23
# 1         1    1  38.0      1      0  71.2833         1           51
# ...

# %%
paired_hist(no, yes, "green", "red")
paired_hist(no2, yes2, "yellow", "purple")
print("No Comparison")
print(pd.DataFrame(no).describe())
print(pd.DataFrame(no2).describe())
print("\nYes Comparison")
print(pd.DataFrame(yes).describe())
print(pd.DataFrame(yes2).describe())
# Out:
# No Comparison
#                  0
# count  3000.000000
# mean      0.843654
# std       0.027725
# min       0.729560
# 25%       0.825581
# 50%       0.843931
# 75%       0.863388
# max       0.923077
#                  0
# count  3000.000000
# mean      0.846179
# std       0.027327
# min       0.726115
# 25%       0.828025
# 50%       0.847458
# 75%       0.865497
# max       0.934132
#
# Yes Comparison
#                  0
# count  3000.000000
# mean      0.728397
# std       0.047870
# min       0.521739
# 25%       0.696629
# 50%       0.730769
# 75%       0.761905
# max       0.868687
#                  0
# count  3000.000000
# mean      0.719024
# std       0.048304
# min       0.521739
# 25%       0.688889
# 50%       0.720721
# 75%       0.752294
# max       0.891089

# %% [markdown]
# ## We can see from the figures above that the inclusion of the name_length composite attribute does not affect the classifier, we turn to more preprocessing

# %% [markdown]
# We can start by adding the cabin levels, where the first letter of the cabin is the level, and compare the probability distributions of the cabin levels in the surviving group vs the non-surviving group

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

first_char = lambda x : x[0]
cabin_levels = df['Cabin'].apply(first_char)
cabin_levels_ordinal = pd.DataFrame(le.fit_transform(cabin_levels))

display(cabin_levels)
display(cabin_levels_ordinal)

prob_plots(cabin_levels_ordinal, 'cabin levels')
# Out:
# 0      O
# 1      C
# 2      O
# 3      C
# 4      O
#       ..
# 886    O
# 887    B
# 888    O
# 889    C
# 890    O
# Name: Cabin, Length: 891, dtype: object
#      0
# 0    7
# 1    2
# 2    7
# 3    2
# 4    7
# ..  ..
# 886  7
# 887  1
# 888  7
# 889  2
# 890  7
#
# [891 rows x 1 columns]

# %% [markdown]
# Now we check to see if the number of the cabin has any correlation

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
